# %%
# %matplotlib inline

# %%
from trajectory_processor import data_initializer
from torch import dist
from critter_actor_critic_continuous import Agent
import numpy as np 


class Environment:
    """

    """
    def __init__(self, DATA_FILE_NAME, trajectory_length = 30, midpoints = 2, EPSILON_PERTURBATIONS = False):
        self.epsilon_pert = EPSILON_PERTURBATIONS
        self.data, self.index_lookup, self.subsequent, self.trajectory = data_initializer(DATA_FILE_NAME, trajectory_length = trajectory_length, midpoints = midpoints)
        if len(self.index_lookup) != len(self.data):
            print("Warning there are some conflicts in the data lookup")
            print("Attempting to correct this problem")
            raise("Just kidding, please edit the environment to fix this problem. I've removed it due to our data having nice qualities. Turns out I was wrong.")
            for x, y in self.data.items():
                y = tuple(y)
                if y in self.index_lookup:
                    if type(self.index_lookup[y]) is int:
                        self.index_lookup[y] = [self.index_lookup[y]]
                    self.index_lookup[y].append(x)
                else:
                    self.index_lookup[y] = x

    def make_start_state(self):
        """Sets implicit start_index and final_index for some number of trajectories"""
        self.start_index, self.final_index = self.trajectory()
        return self.data[self.start_index]

    def state_and_reward(self, current_state, picked_action):
        """
        Should take the current state and the action and return the new state and the reward.
        """
        #current_state, picked_action = current_state.detach().clone(), picked_action.detach().clone()
        lookup_able = tuple(current_state.detach().clone().numpy())
        index = self.index_lookup[lookup_able]
        next_index = self.subsequent[index]
        next_state = self.data[next_index]
        if next_index == self.final_index:
            returned_state = next_state
            done = True
        else:
            returned_state = next_state
            done = False
        #now calculate reward
        if self.epsilon_pert:
            guess = current_state + picked_action
        else:
            guess = picked_action
        reward = dist(guess, next_state)
        reward = reward.detach().numpy()
        return returned_state, np.log(1/(reward+1)), done

# %%
DATA_FILE_NAME = "trajectory_dict.pickle"

# %%
env = Environment(DATA_FILE_NAME)
agent = Agent(alpha=3e-3, beta=0.01, input_dims = 20)
n_games = 100000

fname = 'ACTOR_CRITIC_' + 'lunar_lander_' + \
        str(agent.alpha) + "_" + str(agent.beta) +\
        '_' + str(n_games) + 'games'

scores = []
for i in range(n_games):
    done = False
    observation = env.make_start_state()
    score = 0
    while not done:
        action = agent.choose_action(observation)
        observation_, reward, done = env.state_and_reward(observation ,action)
        score += -1/np.exp(reward)-1
        agent.learn(observation, reward, observation_, done)
        observation = observation_
    if i%200 == 0:
        agent.update_critic_target()
    scores.append(score)

    avg_score = np.mean(scores[-100:])
    print('episode ', i, 'score %.1f' % score,
            'average score %.1f' % avg_score, "    avg single score: ", score/30)
# Out:
# episode  0 score -239.3 average score -239.3     avg single score:  -7.976591984430949
# episode  1 score -218.5 average score -228.9     avg single score:  -7.281810919443767
# episode  2 score -244.4 average score -234.1     avg single score:  -8.146700692176818
# episode  3 score -343.7 average score -261.5     avg single score:  -11.455325778325399
# episode  4 score -219.0 average score -253.0     avg single score:  -7.300124406814575
# episode  5 score -386.4 average score -275.2     avg single score:  -12.879901425043743
# episode  6 score -326.5 average score -282.5     avg single score:  -10.881698870658875
# episode  7 score -411.9 average score -298.7     avg single score:  -13.729179509480794
# episode  8 score -231.8 average score -291.3     avg single score:  -7.728133074442545
# episode  9 score -369.8 average score -299.1     avg single score:  -12.325749079386393
# episode  10 score -346.5 average score -303.4     avg single score:  -11.551551119486492
# episode  11 score -323.8 average score -305.1     avg single score:  -10.794394024213155
# episode  12 score -286.9 average score -303.7     avg single score:  -9.56435783704122
# episode  13 score -205.8 average score -296.7     avg single score:  -6.8607635498046875
# episode  112 score -192.4 average score -269.8     avg single score:  -6.414322527249654
# episode  113 score -201.8 average score -269.8     avg single score:  -6.72530292669932
# episode  114 score -225.6 average score -269.5     avg single score:  -7.51847608089447
# episode  115 score -294.9 average score -270.4     avg single score:  -9.83051152229309
# episode  116 score -282.7 average score -270.9     avg single score:  -9.423359886805217
# episode  117 score -247.9 average score -270.8     avg single score:  -8.263502709070842
# episode  118 score -360.1 average score -272.4     avg single score:  -12.002787025769551
# episode  119 score -383.9 average score -272.5     avg single score:  -12.797052359580993
# episode  120 score -226.0 average score -272.3     avg single score:  -7.5330132404963175
# episode  121 score -661.3 average score -276.8     avg single score:  -22.042317136128744
# episode  122 score -548.8 average score -280.1     avg single score:  -18.29213900566101
# episode  123 score -236.9 average score -279.4     avg single score:  -7.895350408554077
# episode  124 score -263.9 average score -277.7     avg single score:  -8.796118219693502
# episode  125 score -383.7 average score -279.5     avg single score:  -12.791442584991454
# episode  126 score -284.3 average score -279.5     avg single score:  -9.475842475891113
# episode  127 score -196.0 average score -277.7     avg single score:  -6.532783261934916
# episode  128 score -225.9 average score -277.8     avg single score:  -7.531007226308187
# episode  129 score -413.5 average score -279.9     avg single score:  -13.782496213912964
# episode  130 score -231.0 average score -280.0     avg single score:  -7.699765690167745
# episode  131 score -422.2 average score -281.9     avg single score:  -14.074700291951498
# episode  132 score -368.5 average score -283.2     avg single score:  -12.282575011253357
# episode  133 score -244.1 average score -283.5     avg single score:  -8.138110168774922
# episode  134 score -210.2 average score -283.6     avg single score:  -7.005346576372783
# episode  135 score -209.5 average score -282.8     avg single score:  -6.982267832756042
# episode  136 score -269.4 average score -282.2     avg single score:  -8.97840940952301
# episode  137 score -276.7 average score -283.0     avg single score:  -9.222307443618774
# episode  138 score -254.5 average score -283.2     avg single score:  -8.48292822043101
# episode  139 score -217.3 average score -283.2     avg single score:  -7.242085727055867
# episode  140 score -269.0 average score -284.0     avg single score:  -8.966811243693034
# episode  141 score -209.2 average score -282.4     avg single score:  -6.97382899125417
# episode  142 score -281.0 average score -282.1     avg single score:  -9.366973153750102
# episode  143 score -228.6 average score -280.0     avg single score:  -7.620494715372721
# episode  144 score -195.9 average score -277.7     avg single score:  -6.5315326372782385
# episode  145 score -199.6 average score -277.2     avg single score:  -6.653862579663595
# episode  146 score -225.7 average score -277.0     avg single score:  -7.522521376609802
# episode  147 score -305.3 average score -276.4     avg single score:  -10.177472337086995
# episode  148 score -199.3 average score -276.0     avg single score:  -6.642176779111226
# episode  149 score -305.7 average score -276.6     avg single score:  -10.188580091794332
# episode  150 score -195.7 average score -273.0     avg single score:  -6.524051102002462
# episode  151 score -252.3 average score -270.5     avg single score:  -8.408971007664999
# episode  152 score -202.9 average score -269.7     avg single score:  -6.763159426053365
# episode  153 score -196.6 average score -269.1     avg single score:  -6.552489948272705
# episode  154 score -192.4 average score -268.9     avg single score:  -6.4136546611785885
# episode  155 score -190.4 average score -268.8     avg single score:  -6.3463773409525555

# %%
import matplotlib.pyplot as plt

x = [i+1 for i in range(n_games-100)]
plt.plot(scores)
plt.show()

# %%
y1 = scores
y2 = []
mean = lambda x: sum(x)/len(x)
for i in range(len(y1)):
    if i < 50:
        pass
    else:
        avg = mean(y1[(i-50):i])
        y2.append(avg)

# %%
plt.plot(y2)
plt.show()
